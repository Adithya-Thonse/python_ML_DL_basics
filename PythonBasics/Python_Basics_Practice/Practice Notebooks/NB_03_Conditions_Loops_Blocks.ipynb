# %% [markdown]
# ## Practice Notebook

# %% [markdown]
# ## Conditions, Loops and Blocks

# %% [markdown]
# Exercise 1:
#
# * Input two variables, marks_student(marks that a student in the class obtained), max_marks(maximum marks scored in the class).
# * Write one block of 'if' statement to compare whether the marks scored by the student is valid (i.e. less than or equal to max marks) or not.
# * If marks are less than maximum marks in the class and greater than 40, print, welcome to the class, your marks are:(marks of the student).

# %%
max_marks = 98
marks_student = 90

# YOUR CODE HERE

# %% [markdown]
# Exercise 2:
#
# There is a recruitment exercise up for the march past parade in the police academy.
# - The selection procedure for this activity is very simple.
# * If the individual's height is greater than 180 cm, they can participate in the activity.
# __________________________________
#
# * Input height of the individual
# * write one block of 'if' statement compare the height of the individual with 180 cm.
# * this single block will contain three 'print' statements.
# * print, welcome to the academy.
# * print, we will begin march past practice from tomorrow.
# * you will receive your selection letter via mail.

# %%
required_height = 180 
height = # YOUR CODE HERE

# YOUR CODE HERE

# %% [markdown]
# Exercise 3:
#
# In Exercise 2, we were successfully able to notify the participant of the march past parade as to wether they are selected.
# * There is one shortcoming in the Exercise 2, it does not output anything if the participant was not selected.
# * write an 'else' block below the 'if' block discussed in exercise 2.
# * In the 'else' block, print, if the participant was not selected.

# %%
required_height = 180 
height = # YOUR CODE HERE

# YOUR CODE HERE

# %% [markdown]
# Exercise 4:
#
# There is a good news for the participants, if they applied for march past parade but could not make it to the activity because their height is less than 180 cms, they can still participate in Tug-Of-War activity.
#
#
# Write if else if statements to also output the message:
# * if the required height was met, they participated.
# * else, they could not participate in march past.
# * But if their weight is between 65-80, give them a good news that they can participate in Tug-Of-War.

# %%
required_height = 180 
height = # YOUR CODE HERE
weight = # YOUR CODE HERE

# YOUR CODE HERE

# %% [markdown]
# Exercise 5:
#
# * There is one more activity being held in the police academy.
# * It is a 'Tug-Of-War' competition.
# * The only individuals whose height is above 180 cm can attend the event because they are part of march past team.
# * The individuals whose weight is between 65 to 80 Kg will play the game in different teams.
# ____________________________________
# In the similar fashion.
#
# * write 'else-if' ladder to display appropriate messages to the selected individuals.
# * If the requirement of their height is met, they can attend the program.
# * If their weight is between 65 to 70, they will play in Team A.
# * If their weight is between 70 to 75, they will play in Team B.
# * If their weight is between 75 to 80, they will play in Team C.

# %% [markdown]
# If the individual's height is more than 180 cm, they are already a part of another event and hence they will not participate here.

# %%
required_height = 180 
height = # YOUR CODE HERE
weight = # YOUR CODE HERE

# YOUR CODE HERE

# %% [markdown]
# Exercise 6:
#
# There is one shortcoming in the code used for Exercise 5. If the individuals' height is more than 180 but he still applies to play in Tug-Of-War game in the police academy then there will be an issue on the date of event.
#
# It will become difficult for one individual to participate in two activity on the same day.
# _______________________________________________
# To deal with this issue:
# * Change the code in Exercise 5 in a way that if a person's height is more than 180 cms. They will not be selected in any team.
# * Display a message, you are already a part of march past activity, you cannot play in Tug-Of-War.

# %%
required_height = 180 
height = # YOUR CODE HERE
weight = # YOUR CODE HERE

# YOUR CODE HERE

# %% [markdown]
# ### While

# %% [markdown]
# Exercise 7:
#
# Write a 'while' loop to print the sum of 10 positive integers as they pass through the loop one by one.
#
#
# Eg: 1, 1+2=3, 1+2+3=6

# %%
# YOUR CODE HERE

# %% [markdown]
# Exercise 8:
#
# Write a while loop to print the sum of positive integers. Inside the loop check if the sum of postive integers yet is less than 28. If the sum of positive integers at that point is more than 28, print, the sum is more than 28. The iterations should stop at that point.

# %%
# YOUR CODE HERE

# %% [markdown]
# Exercise 9:
#
# In Exercise 8, if sum starts getting bigger than 28, start to print difference between sum and the positive integer.

# %%
# YOUR CODE HERE

# %% [markdown]
# For more Exercises, refer to: https://docs.python-guide.org/intro/learning/
